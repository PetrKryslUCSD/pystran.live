# %% [markdown]
# # Welcome to pystran live demo
#
# [pystran](https://github.com/PetrKryslUCSD/pystran) is a
# Python package for structural analysis with trusses and beams.

# %% [markdown]
# This site is powered by [JupyterLite](https://jupyterlite.readthedocs.io/en/stable/), [Pyodide](https://pyodide.org/en/stable/), [Github Pages](https://pages.github.com/) and [pystran](https://github.com/PetrKryslUCSD/pystran).
#
# Copyright (c) 2026 [Petr Krysl](https://github.com/PetrKryslUCSD)
